# %%
import pyspark
from pyspark.sql import SparkSession
spark = SparkSession.builder.appName("uppercase").getOrCreate()

# %%
upper = spark.sparkContext.textFile("file.txt")

# %%
upper.flatMap(lambda d:d.split(' ')).map(lambda d:d.upper()).collect()
# Out:
# ['EXAMPLE',
#  'OF',
#  'A',
#  'SAMPLE',
#  'FILE',
#  'RDD',
#  '.',
#  'EXAMPLE',
#  'OF',
#  'A',
#  'SAMPLE',
#  'FILE',
#  'RDD',
#  '.',
#  'A',
#  'WHAT',
#  'IS',
#  'ON',
#  'ON',
#  'ON',
#  'A',
#  'IT',
#  'IT',
#  'IT']
