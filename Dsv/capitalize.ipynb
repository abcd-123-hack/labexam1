# %%
import pyspark
from pyspark.sql import SparkSession
spark = SparkSession.builder.appName("Capitalize first word").getOrCreate()

# %%
cap = spark.sparkContext.textFile("file.txt")

# %%
cap.flatMap(lambda d:d.split(' ')).map(lambda d:d.capitalize()).collect()
# Out:
# ['Example',
#  'Of',
#  'A',
#  'Sample',
#  'File',
#  'Rdd',
#  '.',
#  'Example',
#  'Of',
#  'A',
#  'Sample',
#  'File',
#  'Rdd',
#  '.',
#  'A',
#  'What',
#  'Is',
#  'On',
#  'On',
#  'On',
#  'A',
#  'It',
#  'It',
#  'It']
