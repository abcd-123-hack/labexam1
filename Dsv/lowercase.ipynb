# %%
import pyspark
from pyspark.sql import SparkSession
spark = SparkSession.builder.appName("Lower case").getOrCreate()

# %%
lower = spark.sparkContext.textFile("file.txt")

# %%
lower.flatMap(lambda d:d.split(" ")).map(lambda d : d.lower()).collect()
# Out:
# ['example',
#  'of',
#  'a',
#  'sample',
#  'file',
#  'rdd',
#  '.',
#  'example',
#  'of',
#  'a',
#  'sample',
#  'file',
#  'rdd',
#  '.',
#  'a',
#  'what',
#  'is',
#  'on',
#  'on',
#  'on',
#  'a',
#  'it',
#  'it',
#  'it']
